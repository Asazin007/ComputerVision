# %%
import cv2

# %%
import matplotlib.pyplot as plt
image = cv2.imread("/content/img1.jpg",cv2.IMREAD_GRAYSCALE)

# %%
#calculate the histogram of image
histogram = cv2.calcHist([image],[0],None,[256],[0,256])

# %%
plt.figure()
plt.title('Histogram')
plt.xlabel("Intensity")
plt.ylabel("Freq")
plt.plot(histogram)
plt.xlim([0,256])
plt.show()

# %%
#equilize the histogram

# %%
equ =cv2.equalizeHist(image)
hist_equ=cv2.calcHist([equ],[0],None,[256],[0,256])

# %%
from google.colab.patches import cv2_imshow

# %%
plt.plot(hist_equ)
plt.show()
cv2_imshow(image)
cv2_imshow(equ)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1601x664>
# <PIL.Image.Image image mode=L size=1601x664>
# -1
